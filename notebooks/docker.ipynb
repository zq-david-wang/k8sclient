# %%
import docker
docker_client = docker.from_env()

# %%
from docker.errors import APIError
import re
try:
    docker_client.info()
except APIError as e:
    # print dir(e.response)
    message = e.response.json()['message']
    #print message
    m = re.search(r".*server API version:([ 0-9\.]+).*", message)
    if m:
        print m.group(1).strip()
# Out:
# client is newer than server (client API version: 1.26, server API version: 1.24)
# 1.24

# %%
message = "client is newer than server (client API version: 1.26, server API version: 1.24)"
m = re.search(r".*server API version:([ 0-9.]+).*", message)
print m.group(1).strip()
# Out:
# 1.24

# %%
for n in networks:
    print n.name
# Out:
# none
# bridge
# host
# mytestnetwork
# mytestnetwork2

# %%
pd.concat([df1,df2], axis=1)
# Out:
#       a     b     c     d
# a   1.0   2.0   NaN   NaN
# b  10.0  20.0  10.0  20.0
# c   NaN   NaN   1.0   2.0

# %%
log = open("../logs/docker-hang-stack.log").read()

# %%
import re
logs = log.split("\n")

# %%
rs = [re.sub(r'.*dockerd-current\[2393\]:', '', l) for l in logs]
docker_stack = "".join(rs)

# %%
ls = re.split(r"\\n", docker_stack)

# %%
for s in ls:
    print re.sub(r'\\t', '\t', s)
# Out:
#  time="2017-09-27T15:31:26.606927390+08:00" level=info msg="=== BEGIN goroutine stack dump ===
# goroutine 16 [running]:
# github.com/docker/docker/pkg/signal.DumpStacks()
# 	/builddir/build/BUILD/docker-3a094bd354f91c08f76655da01921369b04714b5/_build/src/github.com/docker/docker/pkg/signal/trap.go:74 +0x8f
# github.com/docker/docker/daemon.setupDumpStackTrap.func1(0xc4200741e0)
# 	/builddir/build/BUILD/docker-3a094bd354f91c08f76655da01921369b04714b5/_build/src/github.com/docker/docker/daemon/debugtrap_unix.go:18 +0x73
# created by github.com/docker/docker/daemon.setupDumpStackTrap
# 	/builddir/build/BUILD/docker-3a094bd354f91c08f76655da01921369b04714b5/_build/src/github.com/docker/docker/daemon/debugtrap_unix.go:20 +0xec
#
# goroutine 1 [chan receive, 1758 minutes]:
# main.(*DaemonCli).start(0xc420432c60, 0x0, 0x0)
# 	/builddir/build/BUILD/docker-3a094bd354f91c08f76655da01921369b04714b5/cmd/dockerd/daemon.go:330 +0x1a48
# main.main()
# ...
